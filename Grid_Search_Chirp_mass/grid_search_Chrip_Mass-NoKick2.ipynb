# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import hvplot.dask

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.utils.class_weight import compute_sample_weight, compute_class_weight
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


import scipy

import dask
import dask.dataframe as dd
import dask.array as da
from dask.distributed import Client, SSHCluster
import dask.distributed

import dask_ml
from dask_ml.model_selection import train_test_split
from dask_ml.preprocessing import LabelEncoder

import xgboost as xgb

import mpl_scatter_density
import matplotlib.colors as colors

import csv
from scipy.spatial.distance import jensenshannon as JS

# %% [markdown]
# ## Setting up the cluster

# %%
# cluster.close()

# %%
cluster = SSHCluster(["bhbh-1", "bhbh-1", "bhbh-2", "bhbh-3", "bhbh-4", "bhbh-5"],
                    connect_options={"client_keys": "/home/ubuntu/private/tbertola_key.pem"},
                    worker_options={"n_workers": 4,
                                    "nthreads": 1}, # because each bhbh-* has 4 cores
                    scheduler_options={"port": 8786, "dashboard_address": ":8787"}
                    )
# Out:
# 2023-07-01 05:36:06,049 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:06,047 - distributed.scheduler - INFO - State start
# 2023-07-01 05:36:06,052 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:06,050 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/scheduler-48ivae81', purging
# 2023-07-01 05:36:06,059 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:06,058 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.140:8786
# 2023-07-01 05:36:07,044 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,041 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:38617'
# 2023-07-01 05:36:07,047 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,044 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:42719'
# 2023-07-01 05:36:07,050 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,047 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:33915'
# 2023-07-01 05:36:07,053 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,050 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:38123'
# 2023-07-01 05:36:07,088 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,087 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:35023'
# 2023-07-01 05:36:07,123 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,122 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:38629'
# 2023-07-01 05:36:07,130 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,129 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:43991'
# 2023-07-01 05:36:07,136 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,136 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:44337'
# 2023-07-01 05:36:07,406 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,401 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:34943
# 2023-07-01 05:36:07,407 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,401 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:34943
# 2023-07-01 05:36:07,408 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,401 - distributed.worker - INFO -          dashboard at:          10.67.22.21:35113
# 2023-07-01 05:36:07,409 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,401 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:07,410 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,401 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:07,413 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,401 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:07,414 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,402 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:07,415 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,402 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-hnretqal
# 2023-07-01 05:36:07,416 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,402 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:07,421 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:36453
# 2023-07-01 05:36:07,421 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:36453
# 2023-07-01 05:36:07,422 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO -          dashboard at:          10.67.22.21:40291
# 2023-07-01 05:36:07,423 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:07,424 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:07,426 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:07,427 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:07,434 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-o74r4ord
# 2023-07-01 05:36:07,436 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,410 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:07,443 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,421 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:38499
# 2023-07-01 05:36:07,445 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:38499
# 2023-07-01 05:36:07,445 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO -          dashboard at:          10.67.22.21:38077
# 2023-07-01 05:36:07,446 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:07,447 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:07,448 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:07,449 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:07,450 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-64497353
# 2023-07-01 05:36:07,451 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,422 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:07,452 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,432 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:44323
# 2023-07-01 05:36:07,541 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,540 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:46173'
# 2023-07-01 05:36:07,547 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,546 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:38299'
# 2023-07-01 05:36:07,549 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,549 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:34161'
# 2023-07-01 05:36:07,555 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,552 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:39819'
# 2023-07-01 05:36:07,559 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,556 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:36011'
# 2023-07-01 05:36:07,564 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,562 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:34805'
# 2023-07-01 05:36:07,566 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,564 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:44163'
# 2023-07-01 05:36:07,570 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,568 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:39049'
# 2023-07-01 05:36:07,747 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,739 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:38673'
# 2023-07-01 05:36:07,753 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,746 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:43111'
# 2023-07-01 05:36:07,756 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,749 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:37979'
# 2023-07-01 05:36:07,760 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:07,753 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:46489'
# 2023-07-01 05:36:08,210 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,208 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:39977
# 2023-07-01 05:36:08,214 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:39977
# 2023-07-01 05:36:08,215 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -          dashboard at:         10.67.22.140:34565
# 2023-07-01 05:36:08,217 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,220 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,221 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:37599
# 2023-07-01 05:36:08,222 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,224 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:37599
# 2023-07-01 05:36:08,225 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,226 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-nktl1t__
# 2023-07-01 05:36:08,227 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -          dashboard at:         10.67.22.140:35963
# 2023-07-01 05:36:08,228 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,229 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,229 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:44981
# 2023-07-01 05:36:08,230 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,231 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,232 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:44981
# 2023-07-01 05:36:08,233 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,209 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,233 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-e0nnglqk
# 2023-07-01 05:36:08,234 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO -          dashboard at:         10.67.22.140:46055
# 2023-07-01 05:36:08,235 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,236 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,237 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,238 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,239 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,240 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-vwov__ub
# 2023-07-01 05:36:08,241 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,210 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,264 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,208 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:46783
# 2023-07-01 05:36:08,275 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,221 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:36559
# 2023-07-01 05:36:08,276 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,221 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:36559
# 2023-07-01 05:36:08,277 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,221 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:41769
# 2023-07-01 05:36:08,278 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,221 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:41769
# 2023-07-01 05:36:08,278 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,221 - distributed.worker - INFO -          dashboard at:          10.67.22.31:43059
# 2023-07-01 05:36:08,279 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,221 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,280 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,281 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,291 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,295 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-u407fmzt
# 2023-07-01 05:36:08,296 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,297 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO -          dashboard at:          10.67.22.31:36875
# 2023-07-01 05:36:08,298 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,299 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,222 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,300 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,223 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,300 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,223 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,301 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,223 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-qdtykcwz
# 2023-07-01 05:36:08,312 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,223 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,313 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,225 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:40945
# 2023-07-01 05:36:08,314 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:40945
# 2023-07-01 05:36:08,314 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO -          dashboard at:          10.67.22.31:46469
# 2023-07-01 05:36:08,315 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,316 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,317 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,318 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,319 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-y_tf292l
# 2023-07-01 05:36:08,320 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,226 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,321 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,249 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:33347
# 2023-07-01 05:36:08,321 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,249 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:33347
# 2023-07-01 05:36:08,323 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,249 - distributed.worker - INFO -          dashboard at:         10.67.22.220:42785
# 2023-07-01 05:36:08,323 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,249 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,325 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,249 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,335 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,250 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,337 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,250 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,341 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,250 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-ntv43jiq
# 2023-07-01 05:36:08,347 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,250 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,382 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,252 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:44477
# 2023-07-01 05:36:08,385 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,263 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:46309
# 2023-07-01 05:36:08,386 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:46309
# 2023-07-01 05:36:08,387 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO -          dashboard at:         10.67.22.220:39981
# 2023-07-01 05:36:08,388 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,389 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,390 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,391 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,394 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-h878_knh
# 2023-07-01 05:36:08,395 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,264 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,396 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,292 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:35181
# 2023-07-01 05:36:08,397 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:35181
# 2023-07-01 05:36:08,398 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO -          dashboard at:         10.67.22.220:34333
# 2023-07-01 05:36:08,407 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,408 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,409 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,410 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,411 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-42pzbgfm
# 2023-07-01 05:36:08,412 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,293 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,412 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,294 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:44025
# 2023-07-01 05:36:08,499 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,491 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:44463
# 2023-07-01 05:36:08,504 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,492 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.81:44463
# 2023-07-01 05:36:08,505 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,492 - distributed.worker - INFO -          dashboard at:          10.67.22.81:41905
# 2023-07-01 05:36:08,506 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,492 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,507 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,492 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,508 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,493 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,510 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,493 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,511 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,493 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-ktj77ngz
# 2023-07-01 05:36:08,512 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,493 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,530 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,521 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:36511
# 2023-07-01 05:36:08,531 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,521 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.81:36511
# 2023-07-01 05:36:08,532 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,521 - distributed.worker - INFO -          dashboard at:          10.67.22.81:42563
# 2023-07-01 05:36:08,533 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,522 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,543 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,522 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,544 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,522 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,545 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,522 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,546 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,522 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-96pb6hsz
# 2023-07-01 05:36:08,547 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,522 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,555 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,528 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:42823
# 2023-07-01 05:36:08,556 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,528 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.81:42823
# 2023-07-01 05:36:08,557 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,528 - distributed.worker - INFO -          dashboard at:          10.67.22.81:35783
# 2023-07-01 05:36:08,558 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,529 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-07-01 05:36:08,559 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,529 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,560 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,529 - distributed.worker - INFO -               Threads:                          1
# 2023-07-01 05:36:08,561 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,529 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-07-01 05:36:08,562 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,529 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-kjrgkufj
# 2023-07-01 05:36:08,563 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,529 - distributed.worker - INFO - -------------------------------------------------
# 2023-07-01 05:36:08,564 - distributed.deploy.ssh - INFO - 2023-07-01 05:36:08,538 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:42275

# %%
client=Client(cluster)
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/distributed/client.py:1388: VersionMismatchWarning: Mismatched versions found
#
# +---------+--------+-----------+---------+
# | Package | Client | Scheduler | Workers |
# +---------+--------+-----------+---------+
# | tornado | 6.3.2  | 6.3.2     | 6.2     |
# +---------+--------+-----------+---------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
client
# Out:
# <Client: 'tcp://10.67.22.140:8786' processes=4 threads=4, memory=7.75 GiB>

# %% [markdown]
# ## Data

# %% [raw]
# #import data
# bhbh = dd.read_parquet('/home/ubuntu/data/bag_all_dataset_with_no_kick/*')
# bhbh = bhbh[bhbh['Mass_chirp']<60]

# %% [raw]
# mass_hist = bhbh.Mass_chirp.values.compute()

# %% [raw]
# fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
# ax[0].hist(mass_hist, bins=100);
# ax[1].hist(mass_hist, bins=100, log=True);

# %% [raw]
# plt.hist(mass_hist/bhbh.Mass_chirp.values.max().compute(), bins=100);
# plt.title('Normalize Chirp mass')

# %% [markdown]
# ## Discretizing and introducing labels

# %% [raw]
# min_chirp_mass = bhbh.Mass_chirp.values.min().compute()
# max_chirp_mass = bhbh.Mass_chirp.values.max().compute()
# print(min_chirp_mass, max_chirp_mass)

# %% [raw]
# #Normalization by the max
# bhbh['Mass_chirp_norm'] = bhbh['Mass_chirp']/max_chirp_mass
#
# min_chirp_mass_norm = bhbh.Mass_chirp_norm.values.min().compute()
# max_chirp_mass_norm = bhbh.Mass_chirp_norm.values.max().compute()
# print(min_chirp_mass_norm, max_chirp_mass_norm)

# %% [raw]
# #add column label
# n_bins = 100
# # Define the edges between bins
# counts, bin_edges = da.histogram(bhbh.Mass_chirp_norm.values, bins=n_bins, range=(min_chirp_mass_norm, max_chirp_mass_norm))
#
# # pd.cut each column, with each bin closed on left and open on right
# bhbh['label'] = bhbh['Mass_chirp_norm'].map_partitions(pd.cut, bin_edges, right=True, labels=False, include_lowest=False, meta=int)

# %% [raw]
# test = bhbh[bhbh['label']>=0]['label'].values.compute()
# values, counts = np.unique(test, return_counts=True)
# for v, c in zip(values, counts):
#     print(v,c)

# %% [raw]
# bhbh = bhbh[bhbh['label']>=0].dropna()

# %% [raw]
# ## Splitting the data in train and set
# bhbh_train, bhbh_test = train_test_split(bhbh, train_size=0.7, random_state=1, shuffle=True)
#
# bhbh_train = bhbh_train.reset_index(drop=True) # just for simplicity sake in the final visualisation
# bhbh_test = bhbh_test.reset_index(drop=True)   # and so that we don't mess up later when checking the results

# %% [markdown]
# # Reading from disk

# %% [raw]
# bhbh_train.to_parquet('/mnt/bhbh/train_chirp')
# bhbh_test.to_parquet('/mnt/bhbh/test_chirp')

# %%
n_bins = 100
bhbh_train = dd.read_parquet('/home/ubuntu/train_chirp/*')
bhbh_test = dd.read_parquet('/home/ubuntu/test_chirp/*')

len_train = len(bhbh_train)
len_test = len(bhbh_train)

#selecting no-kick2
bhbh_train = bhbh_train[bhbh_train.No_Kick ==2]
bhbh_test = bhbh_test[bhbh_test.No_Kick ==2]

print(f'% of train with No Kick: {len(bhbh_train)/len_train:.2f}')
print(f'% of test with No Kick: {len(bhbh_test)/len_test:.2f}')
# Out:
# % of train with No Kick: 0.62
# % of test with No Kick: 0.27

# %%
test = bhbh_train['label'].values.compute()
values, counts = np.unique(test, return_counts=True)
for v, c in zip(values, counts):
    print(v,c)
# Out:
# 0.0 10
# 1.0 165
# 2.0 1238
# 3.0 62976
# 4.0 54799
# 5.0 4599
# 6.0 3424
# 7.0 20890
# 8.0 28541
# 9.0 22838
# 10.0 16717
# 11.0 12336
# 12.0 23835
# 13.0 39645
# 14.0 49566
# 15.0 56305
# 16.0 63759
# 17.0 72234
# 18.0 72952
# 19.0 69926
# 20.0 67523
# 21.0 68257
# 22.0 70386
# 23.0 69428
# 24.0 70899
# 25.0 65463
# 26.0 65466
# 27.0 70732
# 28.0 65198
# 29.0 56537
# 30.0 49673
# 31.0 45058
# 32.0 45515
# 33.0 56395
# 34.0 74503
# 35.0 64244
# 36.0 54170
# 37.0 50458
# 38.0 49265
# 39.0 48525
# 40.0 48712
# 41.0 49796
# 42.0 56461
# 43.0 58610
# 44.0 58924
# 45.0 59207
# 46.0 60394
# 47.0 59182
# 48.0 59163
# 49.0 59088
# 50.0 57736
# 51.0 55671
# 52.0 55281
# 53.0 53710
# 54.0 52836
# 55.0 51085
# 56.0 49972
# 57.0 47007
# 58.0 44301
# 59.0 41189
# 60.0 37066
# 61.0 32336
# 62.0 28412
# 63.0 24591
# 64.0 22036
# 65.0 19851
# 66.0 17702
# 67.0 16513
# 68.0 15203
# 69.0 13636
# 70.0 12454
# 71.0 11107
# 72.0 9804
# 73.0 8464
# 74.0 7316
# 75.0 6290
# 76.0 5700
# 77.0 4620
# 78.0 3802
# 79.0 3404
# 80.0 2599
# 81.0 2215
# 82.0 1610
# 83.0 1378
# 84.0 980
# 85.0 641
# 86.0 425
# 87.0 333
# 88.0 270
# 89.0 242
# 90.0 234
# 91.0 185
# 92.0 176
# 93.0 102
# 94.0 114
# 95.0 95
# 96.0 71
# 97.0 62
# 98.0 39
# 99.0 49

# %% [markdown]
# ## Sample weigths

# %%
countings = bhbh_train['label'].to_frame().groupby('label').size().compute()
total_counts = countings.sum()

#Assign to a new column
def assign_weight(i):
    return np.log(total_counts/(n_bins*countings[i])+1) 

bhbh_train['weight'] = bhbh_train['label'].map(assign_weight)

# %% [markdown]
# ## Plot of weights respect to labels

# %% [raw]
# plt.scatter(bhbh_train['label'], bhbh_train['weight'])
# plt.grid()
# plt.show()

# %% [markdown]
# ## Rename of useful columns

# %%
#training
weights = bhbh_train['weight']
labels = bhbh_train['label']
features = bhbh_train[['Mass_0', 'Z_0', 'Mass_1',  'a', 'e', 'alpha']]

#test
features_test = bhbh_test[['Mass_0', 'Z_0', 'Mass_1',  'a', 'e', 'alpha']]
label_test = bhbh_test['label']

# %% [markdown]
# ## Consistency of partitions

# %%
print('Consistency check')
print('features:', type(features), features.npartitions)

print('label', type(labels), labels.npartitions)
print('weight', type(weights), weights.npartitions)
# Out:
# Consistency check
# features: <class 'dask.dataframe.core.DataFrame'> 1800
# label <class 'dask.dataframe.core.Series'> 1800
# weight <class 'dask.dataframe.core.Series'> 1800

# %% [markdown]
# ## XGBoost

# %%
#parameters
max_depth = 0
learning_rate = 0.2
grow_policy = 'lossguide'
n_estimators = 5
max_leaves = 400

param = {'objective': 'multi:softprob',
         'tree_method': 'hist', 
         'n_estimators' : n_estimators, #equivalent to num_boost_round, lets keep it in params
         'grow_policy' : grow_policy, 
         'max_depth' : max_depth,
         'learning_rate' : learning_rate,
         'max_leaves' : max_leaves,
         'num_class': n_bins,
         'n_jobs' : -1,
        }

# %%
dtrain = xgb.dask.DaskDMatrix(client, features, label=labels, weight=weights)
# dtrain = xgb.dask.DaskDMatrix(client, features, label=labels) #test what happens without weight

# %%
# train XGB
bst = xgb.dask.train(client, param, dtrain, evals=[(dtrain, "train")])

# %% [markdown]
# ## Saving and loading the trained model

# %% [raw]
# bst['booster'].save_model(f'bst_Mass_Chirp_{max_depth}_{max_leaves}_new.json')

# %%
bst = xgb.Booster()
bst.load_model('bst_Mass_Chirp_0_400_new.json')

# %%
importances=['weight', 'gain', 'total_gain']
for im in importances:
    feature_important = bst.get_score(importance_type=im)
    keys = list(feature_important.keys())
    values = list(feature_important.values())

    data = pd.DataFrame(data=values, index=keys, columns=["Score: "+im]).sort_values(by = "Score: "+im, ascending=False)
    data.plot(kind='barh', figsize = (5,4)) ## plot top 40 features
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.savefig('Figures/lcp/importance_Chirp_mass_no_kicks'+im+'.png')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## Prediction on test

# %%
## distributions of the probability of each class for each record

output_test = xgb.dask.predict(client, bst, features_test).persist() #already a dataframe

## Predicition of the label with Maximum estimation

predicted_label = output_test.idxmax(axis=1).persist()

## Computing the true labels and the predicted

Y_test = label_test.values.compute()

Y_predicted = predicted_label.values.compute()

# %% [markdown]
# ## Scatter Plot with density

# %%
def using_mpl_scatter_density(fig, x, y):
    ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
    density = ax.scatter_density(x, y, cmap='Reds',
                                 norm=colors.LogNorm(vmin=1, vmax=1000)
                                )
    fig.colorbar(density, label='Number of points per pixel')

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, Y_test, Y_predicted)
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
cm=confusion_matrix(Y_test, Y_predicted)
fig = plt.figure()
ax = fig.add_subplot(111)
pp=ax.matshow(cm.T, norm=colors.LogNorm(vmin=1, vmax=cm.max()), cmap='Reds', origin='lower')
cbar=fig.colorbar(pp)
cbar.ax.get_yaxis().labelpad = -50
cbar.ax.set_ylabel('Counts', rotation=90)
plt.grid(linestyle='dotted')
plt.gca().xaxis.tick_bottom()
plt.xlabel('True q label')
plt.ylabel('Predicted q label')
plt.savefig('Figures/lcp/confusion_matrix_labels_Chirp_Mass_no_kick.png')

# %% [markdown]
# ## Histogram of the q distribution

# %%
plt.hist(Y_test, bins=50, label = 'True labels')
plt.hist(Y_predicted, bins=50, alpha=0.5, label='Predicted labels')
plt.legend()

# %% [markdown]
# # Metrics

# %%
counts_test, _ = np.histogram(Y_test, density=True, bins=n_bins)
counts_predicted, _ = np.histogram(Y_predicted, density=True, bins=n_bins)

# %% [markdown]
# ## Kulback-Leibler metrics

# %%
KL_div = scipy.stats.entropy(counts_predicted, counts_test)

# %%
KL_div
# Out:
# 0.003054161596263368

# %% [markdown]
# ## JS (limited between 0 and 1 when base=2)

# %%
JS_div = JS(counts_test, counts_predicted, base=2)

# %%
JS_div
# Out:
# 0.03309570033239659

# %% [markdown]
# ## Histogram of the Chirp mass distribution with metrics

# %%
plt.hist(Y_test, bins=n_bins, label = 'True label distribution', histtype='step', density=True, color='blue',  linewidth=1.7)#, linestyle='dashed')
plt.hist(Y_predicted, bins=n_bins, label='Predicted label distribution', density=True, color='red')
plt.xlim(0,99)
plt.grid(linestyle='dotted')
plt.xlabel('Label q')
plt.ylabel('Probability [%]')
plt.text(2, 0.03, "Kullback-Liebler: {:.4f}\nJensen-Shannon: {:.4f}".format(KL_div, JS_div),
         ha="left", va="top",
         bbox=dict(boxstyle="round",
                   ec='black',
                   fc='white',
                   )
         )
plt.legend()
plt.savefig('Figures/lcp/hist_Chirp_Mass_nokicks.png')

# %% [markdown]
# ## Histogram of difference of true and prediction

# %%
#95% interval 
diff = (Y_predicted-Y_test)
lower=np.quantile(diff, q=0.025) 
upper= np.quantile(diff, q=0.975)
print(lower, upper)
# Out:
# -5.0 10.0

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,4))

fig.suptitle('Distance true-predicted')
ax[0].hist(-Y_test+Y_predicted, bins=n_bins, density=True, log=True, range=(-n_bins, n_bins));
ax[0].axvline(lower,  label='95% credibility interval', color='red', linestyle='--');
ax[0].axvline(x=upper, color='red', linestyle='--');
ax[0].set_ylabel('Density [Logaritm scale]')
ax[0].set_xlabel(r'$y_{true}-y_{predicted}$')
ax[0].legend()

ax[1].hist(-Y_test+Y_predicted, bins=n_bins, density=True, range=(-n_bins, n_bins));
ax[1].axvline(x=lower, label='95% credibility interval', color='red', linestyle='--');
ax[1].axvline(x=upper, color='red', linestyle='--');
ax[1].set_ylabel('Density')
ax[1].set_xlabel(r'$y_{true}-y_{predicted}$')
ax[1].legend()

ax[2].hist(np.abs(-Y_test+Y_predicted), bins=n_bins, density=True, range=(0, n_bins));
ax[2].set_ylabel('Density')
ax[2].set_xlabel(r'$|y_{true}-y_{predicted}|$')
# Out:
# Text(0.5, 0, '$|y_{true}-y_{predicted}|$')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Create an inset outside the axes
axins = inset_axes(ax, width="100%", height="100%",
                   bbox_to_anchor=(.73, .4, .5, .6),
                   bbox_transform=ax.transAxes, loc=2, borderpad=0)
axins.tick_params(left=False, right=True, labelleft=False, labelright=True)


axins.grid(linestyle='dotted')
ax.grid(linestyle='dotted')
axins.hist(Y_predicted-Y_test, bins=n_bins, density=True, range=(-n_bins, n_bins),
           color='red', linewidth=1.7, log=True, histtype='stepfilled', alpha=0.5)
ax.hist(Y_predicted-Y_test, bins=n_bins, density=True, range=(-n_bins, n_bins),
         alpha=0.5, color='red', label=r'Distribution of $q_{predicted}-q_{true}$')
ax.legend(loc=2)
ax.set_ylabel("Probability [%]")
axins.set_ylabel("Probability log [%]")
ax.set_xlabel(r'$q_{predicted}-q_{true}$')
axins.set_xlabel(r'$q_{predicted}-q_{true}$')
ax.set_ylim(0,0.2)

ax.axvline(x=lower, label='95% credibility interval', color='blue', linestyle='--');
ax.axvline(x=upper, color='blue', linestyle='--');

axins.axvline(x=lower, label='95% credibility interval', color='blue', linestyle='--');
axins.axvline(x=upper, color='blue', linestyle='--');
ax.text(lower-7,0.1, r'Lower 95% CL: $\Delta q_{-}$='+str(lower), rotation=90, va='center')
ax.text(upper+1,0.1, r'Upper 95% CL: $\Delta q_{+}$='+str(upper), rotation=90, va='center')
plt.savefig('Figures/lcp/hist_delta_Chirp_Mass_no_kick.png')
plt.show()

# %% [markdown]
# ## Misura della accuracy

# %%
## Defining a prediction accurate if not further from the true of a value of threshold
def accuracy_threshold(Y_test, Y_predicted, threshold = 5):
    out=np.abs(Y_test-Y_predicted)
    mask = out < threshold
    return np.sum(mask)/len(Y_test)

# %%
accuracy_threshold(Y_test, Y_predicted, 6)
# Out:
# 0.9363325170835524

# %%
def accuracy_exponential(Y_test, Y_predicted, threshold = 25, tau = 25):
    out = np.exp(-np.abs(Y_test-Y_predicted)/tau)
    out = out[np.abs(Y_test-Y_predicted)<threshold]
    return np.sum(out)/len(Y_test)

# %%
accuracy_exponential(Y_test, Y_predicted)
# Out:
# 0.9491800923994632

# %% [markdown]
# ## Grid Search with For Loops

# %% [raw]
# dtrain = xgb.dask.DaskDMatrix(client, features, label=labels, weight=weights)
# # dtrain = xgb.dask.DaskDMatrix(client, features, label=labels) #test what happens without weight

# %% [raw]
# #parameters list
# max_depth_list = [10]
# learning_rate_list = [0.2]
# grow_policy = 'lossguide'
# n_estimators_list = [5]
# max_leave_list = [200, 400]

# %% [raw]
# #GRID SEARCH
#
# #file in wich to save the results of the grid search
# f = open('grid_search_results.csv', 'a')
# writer = csv.writer(f)
#
# #writing the head of the file
# head = ['max_depth', 'learning_rate', 'n_estimators', 'max_leaves', 'KL_div', 'AT', 'AE']
# print('max_depth', 'learning_rate', 'n_estimators', 'max_leaves', 'KL_div', 'AT', 'AE')
# writer.writerow(head)
#
# for max_depth in max_depth_list:
#
#     for learning_rate in learning_rate_list:
#
#         for n_estimators in n_estimators_list:
#
#             for max_leaves in max_leave_list:
#
#
#
#
#                 #list of parameters
#                 param = {'objective': 'multi:softprob',
#                          'tree_method': 'hist',
#                          'n_estimators' : n_estimators, #equivalent to num_boost_round, lets keep it in params
#                          'grow_policy' : grow_policy,
#                          'max_depth' : max_depth,
#                          'learning_rate' : learning_rate,
#                          'max_leaves' : max_leaves,
#                          'num_class': n_bins,
#                          'n_jobs' : -1,
#                         }
#                 #training the model
#                 bst = xgb.dask.train(client, param, dtrain, evals=[(dtrain, "train")])
#
#                 #extracting the predictions
#                 output_test = xgb.dask.predict(client, bst, features_test).persist() #already a dataframe
#                 predicted_label = output_test.idxmax(axis=1).persist()
#                 Y_test = label_test.values.compute()
#                 Y_predicted = predicted_label.values.compute()
#
#                 #Kulback-Leibler
#                 counts_test, _ = np.histogram(Y_test, density=True, bins=n_bins)
#                 counts_predicted, _ = np.histogram(Y_predicted, density=True, bins=n_bins)
#
#                 KL_div = scipy.stats.entropy(counts_predicted, counts_test)
#
#                 #Accuracy threshold
#                 AT = accuracy_threshold(Y_test, Y_predicted, 15)
#
#                 #Accuracy exponential
#                 AE = accuracy_exponential(Y_test, Y_predicted)
#
#                 row= [max_depth, learning_rate, n_estimators, max_leaves, KL_div, AT, AE]
#                 print(max_depth, learning_rate, n_estimators, max_leaves, KL_div, AT, AE)
#                 writer.writerow(row)
#
#
# f.close()

# %% [markdown]
# ## Clustering of probability distribution

# %%
# Defininf a function to order the peaks of the probability distribution
def extract_top_values(row, n_top=3):
    row_sorted = np.sort(row)[::-1]
    return row_sorted[:n_top]

# %%
# Defininf a function to order the peaks of the probability distribution
def extract_id_top_values(row, n_top=3):
    idx_sorted = np.argsort(row)[::-1]
    return np.array(idx_sorted)[:n_top]

# %%
# applying the previous function
top_values = output_test.apply(extract_top_values, axis=1, meta=(None, 'object'))
idx_top_values = output_test.apply(extract_id_top_values, axis=1, meta=(None, 'object'))

# %% [markdown]
# ## Creating a dataframe with all the test set information

# %%
top_values = top_values.compute()
top_values = pd.DataFrame(top_values.to_list(), columns = ['1', '2', '3'])

idx_top_values = idx_top_values.compute()
idx_top_values = pd.DataFrame(idx_top_values.to_list(), columns = ['1', '2', '3'])

for col in idx_top_values.columns:
    top_values[f'idx_{col}']=idx_top_values[col].values   
    
top_values['Y_predicted']=Y_predicted
top_values['Y_test']=Y_test
top_values['Delta_Y']=np.abs(Y_predicted-Y_test)

#adding feature
X_test = features_test.compute()
for col in X_test.columns:
    top_values[col]=X_test[col].values

# %%
top_values
# Out:
#                 1         2         3  idx_1  idx_2  idx_3  Y_predicted  \
# 0        0.197164  0.119886  0.040944     60     61     58           60
# 1        0.115496  0.057462  0.040522     66     61     60           66
# 2        0.111406  0.045357  0.041785     29     32     41           29
# 3        0.070576  0.050466  0.039593     50     51     53           50
# 4        0.372449  0.178897  0.113758     68     69     67           68
# ...           ...       ...       ...    ...    ...    ...          ...
# 1403977  0.072858  0.045059  0.044712     16     17     15           16
# 1403978  0.637367  0.217555  0.008716     56     57     55           56
# 1403979  0.438071  0.179609  0.012055     36     35     37           36
# 1403980  0.236414  0.171189  0.121918     31     35     34           31
# 1403981  0.968234  0.005740  0.001617     25     29     26           25
#
#          Y_test  Delta_Y   Mass_0     Z_0   Mass_1        a        e  alpha
# 0          61.0      1.0  117.304  0.0004   83.859    490.0  0.01200    1.0
# 1          60.0      6.0  103.967  0.0004   94.651  46600.0  0.10200    1.0
# 2          24.0      5.0   57.596  0.0004   30.071    492.0  0.72200    1.0
# 3          45.0      5.0   41.970  0.0004   39.797    149.0  0.04660    1.0
# 4          68.0      0.0   64.356  0.0004   46.568   5080.0  0.01260    1.0
# ...         ...      ...      ...     ...      ...      ...      ...    ...
# 1403977    21.0      5.0   37.869  0.0100   31.319   2230.0  0.23600    3.0
# 1403978    56.0      0.0  123.443  0.0100  120.154   9180.0  0.12400    3.0
# 1403979    36.0      0.0   99.721  0.0100   34.657  16300.0  0.62100    3.0
# 1403980    34.0      3.0   84.835  0.0100   53.354   1060.0  0.00132    3.0
# 1403981    25.0      0.0   53.459  0.0100   38.886  45100.0  0.25500    3.0
#
# [1403982 rows x 15 columns]

# %%
idx_diff = top_values['idx_1']-top_values['idx_2']

# %%
plt.hist(np.abs(idx_diff), bins=99, density=True, log=True, range=(0, idx_diff.max()));

# %% [markdown]
# # Some interesting representations

# %% [markdown]
# ## All the points

# %% [raw]
# sns.scatterplot(data = top_values, x= '1', y='2', hue=np.abs(Y_predicted-Y_test))

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values['1'], top_values['2'])
plt.xlabel('Top probability')
plt.ylabel('Second top probability')
plt.xlim(0,1)
plt.ylim(0,0.5)
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
fontsize=5
fig = plt.figure(figsize=(15, 7))
Z=np.unique(top_values.Z_0)
for i, z in enumerate(Z):
    ax = fig.add_subplot(3, 5, i+1, projection='scatter_density')
    density = ax.scatter_density(x= top_values[(top_values.Z_0==z) & (top_values.Delta_Y == 0) & (top_values['1']>=0.8)]['1'],
                       y=top_values[(top_values.Z_0==z) & (top_values.Delta_Y == 0) & (top_values['1']>=0.8)]['2'],
                       cmap='Reds',
                       norm=colors.LogNorm(vmin=1, vmax=1000))
    ax.set_xlabel('Top probability', fontsize=fontsize, loc='right')
    ax.tick_params(labelsize=fontsize)
    ax.set_ylabel('Second top probability', fontsize=fontsize)
    # ax.set_xlim(0,1)
    # ax.set_ylim(0,0.5)
    
    
    cbar = fig.colorbar(density, ax=ax)
    cbar.ax.set_ylabel(ylabel='Point per pixel', fontsize=fontsize)
    cbar.ax.tick_params(labelsize=fontsize)
    # cbar.set_label(fontsize=fontsize, label='Number of points per pixel')
    
    ax.set_title(f'Z={z}, shown/total={len(top_values[(top_values.Z_0==z) & (top_values.Delta_Y == 0) & (top_values["1"]>=0.8)])/len(top_values[(top_values.Z_0==z) & (top_values["1"]>=0.8)]):.2f}',
                 fontsize=fontsize,
                 loc='left')
    
# sns.scatterplot(data = top_values, x= '1', y='2', hue='Z_0', size=0.001)

# %% [markdown]
# ## Point correctly predicted

# %%
top_values_0 = top_values[top_values['Delta_Y']==0]

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values_0['1'], top_values_0['2'])
plt.show()

# %% [markdown]
# ### Check for the Mass dependency

# %%
fig = plt.figure()
using_mpl_scatter_density(fig,
                          top_values_0[top_values_0['Mass_0']<40]['1'],
                          top_values_0[top_values_0['Mass_0']<40]['2'])
plt.show()

# %% [markdown]
# ## Points with wrong prediction

# %%
top_values_15 = top_values[top_values['Delta_Y']>=15]

# %%
sns.scatterplot(data = top_values_15, x= '1', y='2', hue='alpha', )
# Out:
# <Axes: xlabel='1', ylabel='2'>

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values_15['1'], top_values_15['2'])
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %% [markdown]
# ### Searching for descrepancies in other features

# %%
labels, counts = np.unique(top_values['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum())
plt.xticks(rotation=90);

labels, counts = np.unique(top_values_15['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum(), alpha=0.3)
plt.xticks(rotation=90);
plt.title('Z_0 comparison');

labels, counts = np.unique(top_values_15['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum(), alpha=0.3)
plt.xticks(rotation=90);
plt.title('Z_0 comparison');

# %%
plt.hist(top_values['a'], density=True, bins=50);
plt.hist(top_values_15['a'], density=True, bins=50, alpha=0.5);

# %%
plt.hist(top_values['e'], density=True, bins=50, );
plt.hist(top_values_15['e'], density=True, bins=50, alpha=0.5);

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values['Mass_0'], top_values['Mass_1'])
plt.show()

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values_15['Mass_0'], top_values_15['Mass_1'])
plt.show()

# %%
plt.scatter(top_values['Mass_0'], top_values['Mass_1'], s=0.01)
plt.scatter(top_values_15['Mass_0'], top_values_15['Mass_1'], alpha=0.9, s=0.01)
plt.xlim()
# Out:
# (14.559450000000002, 156.44955)

# %% [markdown]
# ## Attempt of 3D plot

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.scatter3D(top_values_15['1'], top_values_15['2'], top_values_15['3'], s=0.01)

# %% [markdown]
# ## Some simple statistics

# %%
print(f'Fraction of data in the flat region: {len(top_values[top_values["1"]<0.2])/len(top_values):.2f}')

print(f'Fraction of exactly guessed labels: {len(top_values_0)/len(top_values):.2f}')

print( f"Exactly guessed label in flat region / total points in flat region:{  len(top_values_0[top_values_0['1']<0.2])/len(top_values[top_values['1']<0.2])  :.2f}"   )

print( f"Exactly guessed label in flat region / total exactly labels:{  len(  top_values_0[ top_values_0[ '1' ]<0.2 ] )/len(top_values_0)  :.2f}"   )



# len(top_values[top_values['1']<0.2])/len(top_values)
# Out:
# Fraction of data in the flat region: 0.23
# Fraction of exactly guessed labels: 0.59
# Exactly guessed label in flat region / total points in flat region:0.25
# Exactly guessed label in flat region / total exactly labels:0.10

# %%
# cluster.close()

# %% [markdown]
# # Clustering by eye

# %%
one_peak = np.zeros(len(top_values))
one_peak[top_values['1']>0.8] = 1
top_values['Cluster_peak'] = one_peak.astype(int)

# %% [markdown]
# # Plot of cluster

# %%
labels, counts = np.unique(top_values['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum())
plt.xticks(rotation=90);

labels, counts = np.unique(top_values[top_values.Cluster_peak==1]['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum(), alpha=0.3)
plt.xticks(rotation=90);
plt.title('Z_0 comparison');

# %%
plt.hist(top_values['a'], density=True, bins=50);
plt.hist(top_values[top_values.Cluster_peak==1]['a'], density=True, bins=50, alpha=0.5);

# %%
plt.hist(top_values['e'], density=True, bins=50, );
plt.hist(top_values[top_values.Cluster_peak==1]['e'], density=True, bins=50, alpha=0.5);

# %%
bhbh_test.columns
# Out:
# Index(['name', 'Mass_0', 'Z_0', 'SN_0', 'Mass_1', 'SN_1', 'a', 'e', 'alpha',
#        'Mass_0_out', 'Mass_1_out', 'Semimajor', 'Eccentricity', 'GWtime',
#        'BWorldtime', 'RLO', 'CE', 'BSN', 'No_Kick', 'tdelay', 'Mass_max_out',
#        'q', 'Mass_chirp', 'Mass_chirp_norm', 'label'],
#       dtype='object')

# %%
bhbh_test[bhbh_test.Z_0==0.006].groupby("No_Kick").count().compute()
# Out:
#           name  Mass_0    Z_0   SN_0  Mass_1   SN_1      a      e  alpha  \
# No_Kick
# 2.0      89274   89274  89274  89274   89274  89274  89274  89274  89274
#
#          Mass_0_out  ...  BWorldtime    RLO     CE    BSN  tdelay  \
# No_Kick              ...
# 2.0           89274  ...       89274  89274  89274  89274   89274
#
#          Mass_max_out      q  Mass_chirp  Mass_chirp_norm  label
# No_Kick
# 2.0             89274  89274       89274            89274  89274
#
# [1 rows x 24 columns]
