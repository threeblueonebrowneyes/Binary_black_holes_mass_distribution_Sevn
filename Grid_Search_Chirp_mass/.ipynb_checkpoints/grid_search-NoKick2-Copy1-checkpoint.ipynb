# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import hvplot.dask

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.utils.class_weight import compute_sample_weight, compute_class_weight
from sklearn import metrics

import scipy

import dask
import dask.dataframe as dd
import dask.array as da
from dask.distributed import Client, SSHCluster
import dask.distributed

import dask_ml
from dask_ml.model_selection import train_test_split
from dask_ml.preprocessing import LabelEncoder

import xgboost as xgb

import mpl_scatter_density
import matplotlib.colors as colors

import csv
from scipy.spatial.distance import jensenshannon as JS
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ## Setting up the cluster

# %%
# cluster.close()

# %%
cluster = SSHCluster(["bhbh-1", "bhbh-1", "bhbh-2", "bhbh-3", "bhbh-4", "bhbh-5"],
                    connect_options={"client_keys": "/home/ubuntu/private/tbertola_key.pem"},
                    worker_options={"n_workers": 4,
                                    "nthreads": 1}, # because each bhbh-* has 4 cores
                    scheduler_options={"port": 8786, "dashboard_address": ":8787"}
                    )
# Out:
# 2023-06-30 14:10:20,669 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:20,668 - distributed.scheduler - INFO - State start
# 2023-06-30 14:10:20,680 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:20,679 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.140:8786
# 2023-06-30 14:10:21,663 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,661 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:44749'
# 2023-06-30 14:10:21,672 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,671 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:33651'
# 2023-06-30 14:10:21,676 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,675 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:45163'
# 2023-06-30 14:10:21,681 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,681 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:43657'
# 2023-06-30 14:10:21,929 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,929 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:34763'
# 2023-06-30 14:10:21,934 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,931 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:45603'
# 2023-06-30 14:10:21,934 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,933 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:37211'
# 2023-06-30 14:10:21,939 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:21,936 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:43529'
# 2023-06-30 14:10:22,083 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,082 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:36065'
# 2023-06-30 14:10:22,089 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,088 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:45911'
# 2023-06-30 14:10:22,092 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,090 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:37595'
# 2023-06-30 14:10:22,095 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,094 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:33067'
# 2023-06-30 14:10:22,297 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:42357
# 2023-06-30 14:10:22,299 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:42357
# 2023-06-30 14:10:22,302 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO -          dashboard at:          10.67.22.21:39077
# 2023-06-30 14:10:22,304 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,305 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,306 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,307 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,308 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-ots36jnw
# 2023-06-30 14:10:22,309 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,295 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,317 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:36389
# 2023-06-30 14:10:22,318 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:36389
# 2023-06-30 14:10:22,319 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO -          dashboard at:          10.67.22.21:36887
# 2023-06-30 14:10:22,320 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,320 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,322 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,323 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,324 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-4fr65oov
# 2023-06-30 14:10:22,325 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,296 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,325 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,301 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:41449
# 2023-06-30 14:10:22,326 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:41449
# 2023-06-30 14:10:22,327 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO -          dashboard at:          10.67.22.21:42307
# 2023-06-30 14:10:22,328 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,329 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,329 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,330 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,331 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-8qto16co
# 2023-06-30 14:10:22,332 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,302 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,345 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,337 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:40321
# 2023-06-30 14:10:22,581 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,580 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:41157
# 2023-06-30 14:10:22,583 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,580 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:38513
# 2023-06-30 14:10:22,590 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:41157
# 2023-06-30 14:10:22,592 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:38513
# 2023-06-30 14:10:22,594 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -          dashboard at:         10.67.22.140:38771
# 2023-06-30 14:10:22,603 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -          dashboard at:         10.67.22.140:37535
# 2023-06-30 14:10:22,604 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,607 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,609 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,611 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,612 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,616 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,619 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,620 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,621 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-39rmj_cg
# 2023-06-30 14:10:22,623 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-jvqsos2v
# 2023-06-30 14:10:22,624 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,627 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,636 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,581 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:35951
# 2023-06-30 14:10:22,637 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,587 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:35951
# 2023-06-30 14:10:22,638 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,588 - distributed.worker - INFO -          dashboard at:         10.67.22.140:42329
# 2023-06-30 14:10:22,639 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,588 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,639 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,588 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,640 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,588 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,641 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,588 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,642 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,588 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-g8kru5cu
# 2023-06-30 14:10:22,646 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,589 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,648 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,599 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:32933
# 2023-06-30 14:10:22,741 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,738 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:34877
# 2023-06-30 14:10:22,742 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,738 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:34877
# 2023-06-30 14:10:22,743 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO -          dashboard at:         10.67.22.220:42779
# 2023-06-30 14:10:22,745 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,755 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,762 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,763 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,764 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-srrbzzsc
# 2023-06-30 14:10:22,765 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,739 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,770 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,760 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:45193
# 2023-06-30 14:10:22,771 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,760 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:45193
# 2023-06-30 14:10:22,772 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,760 - distributed.worker - INFO -          dashboard at:         10.67.22.220:32823
# 2023-06-30 14:10:22,773 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,760 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,773 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,760 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,775 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,761 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,778 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,761 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,779 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,761 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-8gfbn7ub
# 2023-06-30 14:10:22,780 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,761 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,784 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:39231
# 2023-06-30 14:10:22,787 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:39231
# 2023-06-30 14:10:22,788 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO -          dashboard at:         10.67.22.220:42023
# 2023-06-30 14:10:22,789 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:22,790 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,791 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:22,792 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:22,793 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,771 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-8oci6wso
# 2023-06-30 14:10:22,795 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,772 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:22,798 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:22,787 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:44491
# 2023-06-30 14:10:23,093 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,089 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:33891'
# 2023-06-30 14:10:23,098 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,095 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:41669'
# 2023-06-30 14:10:23,101 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,098 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:32949'
# 2023-06-30 14:10:23,105 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,102 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:33251'
# 2023-06-30 14:10:23,760 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,756 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:41459'
# 2023-06-30 14:10:23,767 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,764 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:42289'
# 2023-06-30 14:10:23,770 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,767 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:43671'
# 2023-06-30 14:10:23,774 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,771 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:39155'
# 2023-06-30 14:10:23,826 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,821 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:42335
# 2023-06-30 14:10:23,828 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.81:42335
# 2023-06-30 14:10:23,829 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -          dashboard at:          10.67.22.81:43781
# 2023-06-30 14:10:23,830 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:23,832 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:23,833 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:23,834 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:23,835 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-g47vly5v
# 2023-06-30 14:10:23,837 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:23,838 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:42605
# 2023-06-30 14:10:23,839 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,822 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.81:42605
# 2023-06-30 14:10:23,841 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO -          dashboard at:          10.67.22.81:42903
# 2023-06-30 14:10:23,842 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:23,843 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:23,844 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:23,854 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:23,855 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-4b28i366
# 2023-06-30 14:10:23,856 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,823 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:23,858 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,840 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:34213
# 2023-06-30 14:10:23,859 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,840 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.81:34213
# 2023-06-30 14:10:23,860 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO -          dashboard at:          10.67.22.81:35527
# 2023-06-30 14:10:23,861 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:23,862 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:23,863 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:23,865 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:23,868 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-kla4wh51
# 2023-06-30 14:10:23,869 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,841 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:23,877 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:23,852 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:45047
# 2023-06-30 14:10:24,462 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,456 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:33921
# 2023-06-30 14:10:24,464 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:33921
# 2023-06-30 14:10:24,465 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO -          dashboard at:          10.67.22.31:36235
# 2023-06-30 14:10:24,466 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:24,467 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:24,467 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:24,468 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:24,469 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-5uquk24k
# 2023-06-30 14:10:24,473 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,457 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:24,484 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,479 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:38055
# 2023-06-30 14:10:24,485 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,479 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:38055
# 2023-06-30 14:10:24,486 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,479 - distributed.worker - INFO -          dashboard at:          10.67.22.31:42073
# 2023-06-30 14:10:24,487 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,479 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:24,487 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,479 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:38847
# 2023-06-30 14:10:24,489 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:24,490 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:38847
# 2023-06-30 14:10:24,491 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:24,496 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -          dashboard at:          10.67.22.31:38231
# 2023-06-30 14:10:24,496 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:24,497 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-30 14:10:24,498 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-wg60ibwy
# 2023-06-30 14:10:24,499 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:24,500 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -               Threads:                          1
# 2023-06-30 14:10:24,501 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:24,502 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2023-06-30 14:10:24,503 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-gjtbxr_j
# 2023-06-30 14:10:24,504 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,480 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-30 14:10:24,508 - distributed.deploy.ssh - INFO - 2023-06-30 14:10:24,505 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:46363

# %%
client=Client(cluster)
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/distributed/client.py:1388: VersionMismatchWarning: Mismatched versions found
#
# +---------+--------+-----------+------------------+
# | Package | Client | Scheduler | Workers          |
# +---------+--------+-----------+------------------+
# | tornado | 6.3.2  | 6.3.2     | {'6.3.2', '6.2'} |
# +---------+--------+-----------+------------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
client
# Out:
# <Client: 'tcp://10.67.22.140:8786' processes=16 threads=16, memory=31.03 GiB>

# %% [markdown]
# ## Data

# %% [raw]
# #defin the value of q to drop
# q_drop = 0.2
#
# #import data
# bhbh = dd.read_parquet('/home/ubuntu/data/bag_all_dataset_with_no_kick/*')
#
# #Masking on the data
# bhbh = bhbh[bhbh['q'] > q_drop] #dropping the value of q under q_drop
# #bhbh = bhbh[ bhbh['No_Kick'] == 2] #taking only the binaries without kick

# %% [raw]
# ## Discretizing and introducing labels

# %% [raw]
# #add column label
# n_bins = 100
# # Define the edges between bins
# counts, bin_edges = da.histogram(bhbh.q.values, bins=n_bins, range=(q_drop,1.0))
#
# # pd.cut each column, with each bin closed on left and open on right
# bhbh['label'] = bhbh['q'].map_partitions(pd.cut, bin_edges, right=True, labels=False, include_lowest=False)

# %% [raw]
# ## Splitting the data in train and set

# %% [raw]
# bhbh_train, bhbh_test = train_test_split(bhbh, train_size=0.7, random_state=1, shuffle=True)
#
# bhbh_train = bhbh_train.reset_index(drop=True) # just for simplicity sake in the final visualisation
# bhbh_test = bhbh_test.reset_index(drop=True)   # and so that we don't mess up later when checking the results
#
# #Repartition for xgboost
# bhbh_train = bhbh_train#.repartition(240)

# %%
n_bins = 100
bhbh_train = dd.read_parquet('/home/ubuntu/train/*')

# %%
len(bhbh_train)
# Out:
# 5242023

# %%
bhbh_train = bhbh_train[bhbh_train.No_Kick ==2]

# %%
len(bhbh_train)
# Out:
# 3271433

# %%
bhbh_test = dd.read_parquet('/home/ubuntu/test/*')

# %%
len(bhbh_test)
# Out:
# 2247825

# %%
bhbh_test = bhbh_test[bhbh_test.No_Kick ==2]

# %%
len(bhbh_test)
# Out:
# 1403123

# %% [markdown]
# ## Sample weigths

# %%
countings = bhbh_train['label'].to_frame().groupby('label').size().compute()
total_counts = countings.sum()

#Assign to a new column
def assign_weight(i):
    return np.log(total_counts/(n_bins*countings[i])+1) 

bhbh_train['weight'] = bhbh_train['label'].map(assign_weight)

# %% [markdown]
# ## Plot of weights respect to labels

# %% [raw]
# plt.scatter(bhbh_train['label'], bhbh_train['weight'])
# plt.grid()
# plt.show()

# %% [markdown]
# ## Rename of useful columns

# %%
#training
weights = bhbh_train['weight']
labels = bhbh_train['label']
features = bhbh_train[['Mass_0', 'Z_0', 'Mass_1',  'a', 'e', 'alpha']]

#test
features_test = bhbh_test[['Mass_0', 'Z_0', 'Mass_1',  'a', 'e', 'alpha']]
label_test = bhbh_test['label']

# %% [markdown]
# ## Consistency of partitions

# %%
print('Consistency check')
print('features:', type(features), features.npartitions)

print('label', type(labels), labels.npartitions)
print('weight', type(weights), weights.npartitions)
# Out:
# Consistency check
# features: <class 'dask.dataframe.core.DataFrame'> 1800
# label <class 'dask.dataframe.core.Series'> 1800
# weight <class 'dask.dataframe.core.Series'> 1800

# %% [markdown]
# ## XGBoost

# %%
#parameters
max_depth = 0
learning_rate = 0.2
grow_policy = 'lossguide'
n_estimators = 5
max_leaves = 400

param = {'objective': 'multi:softprob',
         'tree_method': 'hist', 
         'n_estimators' : n_estimators, #equivalent to num_boost_round, lets keep it in params
         'grow_policy' : grow_policy, 
         'max_depth' : max_depth,
         'learning_rate' : learning_rate,
         'max_leaves' : max_leaves,
         'num_class': n_bins,
         'n_jobs' : -1,
        }

# %%
dtrain = xgb.dask.DaskDMatrix(client, features, label=labels, weight=weights)
# dtrain = xgb.dask.DaskDMatrix(client, features, label=labels) #test what happens without weight

# %%
# train XGB
bst = xgb.dask.train(client, param, dtrain, evals=[(dtrain, "train")])

# %% [markdown]
# ## Saving and loading the trained model

# %%
bst['booster'].save_model(f'bst{max_depth}_{max_leaves}_NoKick2_new.json')

# %%
bst = xgb.Booster()
bst.load_model('bst0_400_NoKick2_new.json')

# %%
plt.barh(features.columns, bst.get_fscore().values())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## Prediction on test

# %%
## distributions of the probability of each class for each record

output_test = xgb.dask.predict(client, bst, features_test).persist() #already a dataframe

## Predicition of the label with Maximum estimation

predicted_label = output_test.idxmax(axis=1).persist()

## Computing the true labels and the predicted

Y_test = label_test.values.compute()

Y_predicted = predicted_label.values.compute()

# %% [markdown]
# ## Scatter Plot with density

# %%
def using_mpl_scatter_density(fig, x, y):
    ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
    density = ax.scatter_density(x, y, cmap='Reds',
                                 norm=colors.LogNorm(vmin=1, vmax=1000))
    fig.colorbar(density, label='Number of points per pixel')

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, Y_test, Y_predicted)
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %% [markdown]
# ## Histogram of the q distribution

# %%
plt.hist(Y_test, bins=n_bins, label = 'True labels')
plt.hist(Y_predicted, bins=n_bins, alpha=0.5, label='Predicted labels')
plt.legend()

# %% [markdown]
# # Metrics

# %%
counts_test, _ = np.histogram(Y_test, density=True, bins=n_bins)
counts_predicted, _ = np.histogram(Y_predicted, density=True, bins=n_bins)

# %% [markdown]
# ## Kulback-Leibler metrics

# %%
KL_div = scipy.stats.entropy(counts_predicted, counts_test)

# %%
KL_div
# Out:
# 0.00686334814705663

# %% [markdown]
# ## JS (limited between 0 and 1 when base=2)

# %%
JS_div = JS(counts_test, counts_predicted, base=2)

# %%
JS_div
# Out:
# 0.049075011900384005

# %% [markdown]
# ## Histogram of difference of true and prediction

# %%
#95% interval 
diff = (Y_predicted-Y_test)
lower=np.quantile(diff, q=0.025) 
upper= np.quantile(diff, q=0.975)
print(lower, upper)
# Out:
# -31.0 15.0

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,4))

fig.suptitle('Distance true-predicted')
ax[0].hist(-Y_test+Y_predicted, bins=n_bins, density=True, log=True, range=(-n_bins, n_bins));
ax[0].axvline(lower,  label='95% credibility interval', color='red', linestyle='--');
ax[0].axvline(x=upper, color='red', linestyle='--');
ax[0].set_ylabel('Density [Logaritm scale]')
ax[0].set_xlabel(r'$y_{true}-y_{predicted}$')
ax[0].legend()

ax[1].hist(-Y_test+Y_predicted, bins=n_bins, density=True, range=(-n_bins, n_bins));
ax[1].axvline(x=lower, label='95% credibility interval', color='red', linestyle='--');
ax[1].axvline(x=upper, color='red', linestyle='--');
ax[1].set_ylabel('Density')
ax[1].set_xlabel(r'$y_{true}-y_{predicted}$')
ax[1].legend()

ax[2].hist(np.abs(-Y_test+Y_predicted), bins=n_bins, density=True, range=(0, n_bins));
ax[2].set_ylabel('Density')
ax[2].set_xlabel(r'$|y_{true}-y_{predicted}|$')
# Out:
# Text(0.5, 0, '$|y_{true}-y_{predicted}|$')

# %% [markdown]
# ## Misura della accuracy

# %%
## Defining a prediction accurate if not further from the true of a value of threshold
def accuracy_threshold(Y_test, Y_predicted, threshold = 5):
    out=np.abs(Y_test-Y_predicted)
    mask = out < threshold
    return np.sum(mask)/len(Y_test)

# %%
accuracy_threshold(Y_test, Y_predicted, 15)
# Out:
# 0.9162753372298793

# %%
def accuracy_exponential(Y_test, Y_predicted, threshold = 25, tau = 25):
    out = np.exp(-np.abs(Y_test-Y_predicted)/tau)
    out = out[np.abs(Y_test-Y_predicted)<threshold]
    return np.sum(out)/len(Y_test)

# %%
accuracy_exponential(Y_test, Y_predicted)
# Out:
# 0.863576512638665

# %% [markdown]
# ## Grid Search with For Loops

# %% [raw]
# dtrain = xgb.dask.DaskDMatrix(client, features, label=labels, weight=weights)
# # dtrain = xgb.dask.DaskDMatrix(client, features, label=labels) #test what happens without weight

# %% [raw]
# #parameters list
# max_depth_list = [10]
# learning_rate_list = [0.2]
# grow_policy = 'lossguide'
# n_estimators_list = [5]
# max_leave_list = [200, 400]

# %% [raw]
# #GRID SEARCH
#
# #file in wich to save the results of the grid search
# f = open('grid_search_results.csv', 'a')
# writer = csv.writer(f)
#
# #writing the head of the file
# head = ['max_depth', 'learning_rate', 'n_estimators', 'max_leaves', 'KL_div', 'AT', 'AE']
# print('max_depth', 'learning_rate', 'n_estimators', 'max_leaves', 'KL_div', 'AT', 'AE')
# writer.writerow(head)
#
# for max_depth in max_depth_list:
#
#     for learning_rate in learning_rate_list:
#
#         for n_estimators in n_estimators_list:
#
#             for max_leaves in max_leave_list:
#
#
#
#
#                 #list of parameters
#                 param = {'objective': 'multi:softprob',
#                          'tree_method': 'hist',
#                          'n_estimators' : n_estimators, #equivalent to num_boost_round, lets keep it in params
#                          'grow_policy' : grow_policy,
#                          'max_depth' : max_depth,
#                          'learning_rate' : learning_rate,
#                          'max_leaves' : max_leaves,
#                          'num_class': n_bins,
#                          'n_jobs' : -1,
#                         }
#                 #training the model
#                 bst = xgb.dask.train(client, param, dtrain, evals=[(dtrain, "train")])
#
#                 #extracting the predictions
#                 output_test = xgb.dask.predict(client, bst, features_test).persist() #already a dataframe
#                 predicted_label = output_test.idxmax(axis=1).persist()
#                 Y_test = label_test.values.compute()
#                 Y_predicted = predicted_label.values.compute()
#
#                 #Kulback-Leibler
#                 counts_test, _ = np.histogram(Y_test, density=True, bins=n_bins)
#                 counts_predicted, _ = np.histogram(Y_predicted, density=True, bins=n_bins)
#
#                 KL_div = scipy.stats.entropy(counts_predicted, counts_test)
#
#                 #Accuracy threshold
#                 AT = accuracy_threshold(Y_test, Y_predicted, 15)
#
#                 #Accuracy exponential
#                 AE = accuracy_exponential(Y_test, Y_predicted)
#
#                 row= [max_depth, learning_rate, n_estimators, max_leaves, KL_div, AT, AE]
#                 print(max_depth, learning_rate, n_estimators, max_leaves, KL_div, AT, AE)
#                 writer.writerow(row)
#
#
# f.close()

# %% [markdown]
# ## Clustering of probability distribution

# %%
# Defininf a function to order the peaks of the probability distribution
def extract_top_values(row, n_top=3):
    row_sorted = np.sort(row)[::-1]
    return row_sorted[:n_top]

# %%
# Defininf a function to order the peaks of the probability distribution
def extract_id_top_values(row, n_top=3):
    idx_sorted = np.argsort(row)[::-1]
    return np.array(idx_sorted)[:n_top]

# %%
# applying the previous function
top_values = output_test.apply(extract_top_values, axis=1, meta=(None, 'object'))
idx_top_values = output_test.apply(extract_id_top_values, axis=1, meta=(None, 'object'))

# %% [markdown]
# ## Creating a dataframe with all the test set information

# %%
top_values = top_values.compute()
top_values = pd.DataFrame(top_values.to_list(), columns = ['1', '2', '3'])

idx_top_values = idx_top_values.compute()
idx_top_values = pd.DataFrame(idx_top_values.to_list(), columns = ['1', '2', '3'])

for col in idx_top_values.columns:
    top_values[f'idx_{col}']=idx_top_values[col].values   
    
top_values['Y_predicted']=Y_predicted
top_values['Y_test']=Y_test
top_values['Delta_Y']=np.abs(Y_predicted-Y_test)

#adding feature
X_test = features_test.compute()
for col in X_test.columns:
    top_values[col]=X_test[col].values

# %%
top_values
# Out:
#                 1         2         3  idx_1  idx_2  idx_3  Y_predicted  \
# 0        0.087401  0.048021  0.043157     95     92     94           95
# 1        0.165943  0.109442  0.089708     87     86     85           87
# 2        0.146319  0.061782  0.060110     83     84     82           83
# 3        0.199383  0.093982  0.037402     25     26     24           25
# 4        0.093293  0.052993  0.040848     93     89     90           93
# ...           ...       ...       ...    ...    ...    ...          ...
# 1403118  0.072600  0.072452  0.054915     93     94     95           93
# 1403119  0.913907  0.029013  0.010439     99     98     96           99
# 1403120  0.168785  0.114420  0.094256     81     82     80           81
# 1403121  0.405642  0.333352  0.011428     41     40     38           41
# 1403122  0.095566  0.050481  0.043745     82     79     80           82
#
#          Y_test  Delta_Y   Mass_0     Z_0  Mass_1        a       e  alpha
# 0            82       13   60.831  0.0004  42.856    503.0  0.0606    1.0
# 1            85        2   58.943  0.0004  51.689  40200.0  0.2780    1.0
# 2            83        0   68.488  0.0004  45.524  22400.0  0.1760    1.0
# 3            25        0   58.378  0.0004  23.074  84100.0  0.7290    1.0
# 4            91        2   33.537  0.0004  22.996     76.2  0.2720    1.0
# ...         ...      ...      ...     ...     ...      ...     ...    ...
# 1403118      89        4   69.694  0.0100  66.735    272.0  0.0448    3.0
# 1403119      99        0   40.070  0.0100  40.036  25000.0  0.0786    3.0
# 1403120      79        2   55.556  0.0100  48.744  26000.0  0.4070    3.0
# 1403121      40        1  106.439  0.0100  43.318   5160.0  0.6120    3.0
# 1403122      74        8   96.606  0.0100  73.664    613.0  0.0921    3.0
#
# [1403123 rows x 15 columns]

# %%
idx_diff = top_values['idx_1']-top_values['idx_2']

# %%
plt.hist(np.abs(idx_diff), bins=99, density=True, log=True);

# %%
lower=np.quantile(np.abs(idx_diff), q=0.8) 
lower
# Out:
# 4.0

# %% [markdown]
# # Some interesting representations

# %% [markdown]
# ## All the points

# %% [raw]
# sns.scatterplot(data = top_values, x= '1', y='2', hue=np.abs(Y_predicted-Y_test))

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values['1'], top_values['2'])
plt.xlabel('Top probability')
plt.ylabel('Second top probability')
plt.xlim(0,1)
plt.ylim(0,0.5)
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
fontsize=5
fig = plt.figure(figsize=(15, 7))
Z=np.unique(top_values.Z_0)
for i, z in enumerate(Z):
    ax = fig.add_subplot(3, 5, i+1, projection='scatter_density')
    density = ax.scatter_density(x= top_values[(top_values.Z_0==z) & (top_values.Delta_Y == 0) & (top_values['1']>=0.8)]['1'],
                       y=top_values[(top_values.Z_0==z) & (top_values.Delta_Y == 0) & (top_values['1']>=0.8)]['2'],
                       cmap='Reds',
                       norm=colors.LogNorm(vmin=1, vmax=1000))
    ax.set_xlabel('Top probability', fontsize=fontsize, loc='right')
    ax.tick_params(labelsize=fontsize)
    ax.set_ylabel('Second top probability', fontsize=fontsize)
    # ax.set_xlim(0,1)
    # ax.set_ylim(0,0.5)
    
    
    cbar = fig.colorbar(density, ax=ax)
    cbar.ax.set_ylabel(ylabel='Point per pixel', fontsize=fontsize)
    cbar.ax.tick_params(labelsize=fontsize)
    # cbar.set_label(fontsize=fontsize, label='Number of points per pixel')
    
    ax.set_title(f'Z={z}, shown/total={len(top_values[(top_values.Z_0==z) & (top_values.Delta_Y == 0) & (top_values["1"]>=0.8)])/len(top_values[(top_values.Z_0==z) & (top_values["1"]>=0.8)]):.2f}',
                 fontsize=fontsize,
                 loc='left')
    
# sns.scatterplot(data = top_values, x= '1', y='2', hue='Z_0', size=0.001)

# %%
fontsize=5
fig = plt.figure(figsize=(15, 7))
Z=np.unique(top_values.Z_0)
for i, z in enumerate(Z):
    ax = fig.add_subplot(3, 5, i+1, projection='scatter_density')
    density = ax.scatter_density(x= top_values[(top_values.Z_0==z) & (top_values.Delta_Y <= 2) & (top_values['1']>=0.8)]['1'],
                       y=top_values[(top_values.Z_0==z) & (top_values.Delta_Y <= 2) & (top_values['1']>=0.8)]['2'],
                       cmap='Reds',
                       norm=colors.LogNorm(vmin=1, vmax=1000))
    ax.set_xlabel('Top probability', fontsize=fontsize, loc='right')
    ax.tick_params(labelsize=fontsize)
    ax.set_ylabel('Second top probability', fontsize=fontsize)
    # ax.set_xlim(0,1)
    # ax.set_ylim(0,0.5)
    
    
    cbar = fig.colorbar(density, ax=ax)
    cbar.ax.set_ylabel(ylabel='Point per pixel', fontsize=fontsize)
    cbar.ax.tick_params(labelsize=fontsize)
    # cbar.set_label(fontsize=fontsize, label='Number of points per pixel')
    
    ax.set_title(f'Z={z}, shown/total={len(top_values[(top_values.Z_0==z) & (top_values.Delta_Y <= 2) & (top_values["1"]>=0.8)])/len(top_values[(top_values.Z_0==z) & (top_values["1"]>=0.8)]):.2f}',
                 fontsize=fontsize,
                 loc='left')
    
# sns.scatterplot(data = top_values, x= '1', y='2', hue='Z_0', size=0.001)

# %% [markdown]
# ## Point correctly predicted

# %%
top_values_0 = top_values[top_values['Delta_Y']==0]

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values_0['1'], top_values_0['2'])
plt.xlim(0,1)
plt.ylim(0,0.5)
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %% [markdown]
# ### Check for the Mass dependency

# %%
fig = plt.figure()
using_mpl_scatter_density(fig,
                          top_values_0[top_values_0['Mass_0']<40]['1'],
                          top_values_0[top_values_0['Mass_0']<40]['2'])
plt.xlim(0,1)
plt.ylim(0,0.5)
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %% [markdown]
# ## Points with wrong prediction

# %%
top_values_15 = top_values[top_values['Delta_Y']>=6]

# %% [raw]
# sns.scatterplot(data = top_values_15, x= '1', y='2', hue='alpha', )

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values_15['1'], top_values_15['2'])
plt.xlim(0,1)
plt.ylim(0,0.5)
plt.show()

# %% [markdown]
# ### Searching for descrepancies in other features

# %%
labels, counts = np.unique(top_values['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum(),  label='All predictions')
plt.xticks(rotation=90);

labels, counts = np.unique(top_values_15['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum(), alpha=0.3, label='Predicted w/ error >=15 or 6')
plt.xticks(rotation=90);
plt.title('Z_0 comparison');
plt.ylabel('Fractions of systems')
plt.xlabel('Z')
plt.legend()

# labels, counts = np.unique(top_values_15['Z_0'].values, return_counts=True)
# plt.bar( labels.astype(str), counts/counts.sum(), alpha=0.3)
# plt.xticks(rotation=90);
# plt.title('Z_0 comparison');

# %%
plt.hist(top_values['a'], density=True, bins=50, log=True);
plt.hist(top_values_15['a'], density=True, bins=50, alpha=0.5, log=True);

# %%
plt.hist(top_values['e'], density=True, bins=50, );
plt.hist(top_values_15['e'], density=True, bins=50, alpha=0.5);

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values['Mass_0'], top_values['Mass_1'])
plt.xlabel('Mass_0')
plt.ylabel('Mass_1')
plt.show()
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values['Mass_0'], top_values['Mass_1'])
plt.xlim(20,60)
plt.ylim(10,40)
plt.xlabel('Mass_0')
plt.ylabel('Mass_1')
plt.show()

# %%
fig = plt.figure()
using_mpl_scatter_density(fig, top_values_15['Mass_0'], top_values_15['Mass_1'])
plt.xlabel('Mass_0')
plt.ylabel('Mass_1')
plt.show()

# %%
plt.scatter(top_values['Mass_0'], top_values['Mass_1'], s=0.01)
plt.scatter(top_values_15['Mass_0'], top_values_15['Mass_1'], alpha=0.5, s=0.01)

# %% [markdown]
# ## Attempt of 3D plot

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.scatter3D(top_values_15['1'], top_values_15['2'], top_values_15['3'], s=0.01)

# %% [markdown]
# ## Some simple statistics

# %%
print(f'Fraction of data in the flat region: {len(top_values[top_values["1"]<0.2])/len(top_values):.2f}')

print(f'Fraction of exactly guessed labels: {len(top_values_0)/len(top_values):.2f}')

print( f"Exactly guessed label in flat region / total points in flat region:{  len(top_values_0[top_values_0['1']<0.2])/len(top_values[top_values['1']<0.2])  :.2f}"   )

print( f"Exactly guessed label in flat region / total exactly flat labels:{  len(  top_values_0[ top_values_0[ '1' ]<0.2 ] )/len(top_values_0)  :.2f}"   )

# len(top_values[top_values['1']<0.2])/len(top_values)
# Out:
# Fraction of data in the flat region: 0.72
# Fraction of exactly guessed labels: 0.30
# Exactly guessed label in flat region / total points in flat region:0.20
# Exactly guessed label in flat region / total exactly flat labels:0.47

# %%
# cluster.close()

# %% [markdown]
# # Clustering by eye

# %%
one_peak = np.zeros(len(top_values))
one_peak[top_values['1']>0.8] = 1
top_values['Cluster_peak'] = one_peak.astype(int)

# %% [markdown]
# # Plot of cluster

# %%
labels, counts = np.unique(top_values['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum())
plt.xticks(rotation=90);

labels, counts = np.unique(top_values[top_values.Cluster_peak==1]['Z_0'].values, return_counts=True)
plt.bar( labels.astype(str), counts/counts.sum(), alpha=0.3)
plt.xticks(rotation=90);
plt.title('Z_0 comparison');

# %%
plt.hist(top_values['a'], density=True, bins=50);
plt.hist(top_values[top_values.Cluster_peak==1]['a'], density=True, bins=50, alpha=0.5);

# %%
plt.hist(top_values['e'], density=True, bins=50, );
plt.hist(top_values[top_values.Cluster_peak==1]['e'], density=True, bins=50, alpha=0.5);

# %%
bhbh_test.columns
# Out:
# Index(['name', 'Mass_0', 'Z_0', 'SN_0', 'Mass_1', 'SN_1', 'a', 'e', 'alpha',
#        'Mass_0_out', 'Mass_1_out', 'Semimajor', 'Eccentricity', 'GWtime',
#        'BWorldtime', 'RLO', 'CE', 'BSN', 'No_Kick', 'tdelay', 'Mass_max_out',
#        'q', 'Mass_chirp', 'label'],
#       dtype='object')

# %%
bhbh_test[bhbh_test.Z_0==0.006].groupby("No_Kick").count().compute()
# Out:
#           name  Mass_0    Z_0   SN_0  Mass_1   SN_1      a      e  alpha  \
# No_Kick
# 2.0      88916   88916  88916  88916   88916  88916  88916  88916  88916
#
#          Mass_0_out  ...  GWtime  BWorldtime    RLO     CE    BSN  tdelay  \
# No_Kick              ...
# 2.0           88916  ...   88916       88916  88916  88916  88916   88916
#
#          Mass_max_out      q  Mass_chirp  label
# No_Kick
# 2.0             88916  88916       88916  88916
#
# [1 rows x 23 columns]

# %%
len(bhbh_train)
# Out:
# 3271433
