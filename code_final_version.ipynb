# %% [markdown]
# # Code for preprocessing with bag

# %% [markdown]
# This is the final version of the code of our project that has managed to process the hole dataset of 1.7 TB.
#
# In this notebook we create a bag that contains lists of paths of files.
# Each list contains the paths of the output, evolved and logfile of the same thread.
# The preprocessing function is written in a way that takes in input a list containing the paths of an output file, an evolved file and a logfile and creates a dataframe cotaining the useful informations.
# Applying this function to the bag through the `bag.map()` command we obtain a bag of dataframes.
# In the end, we extract a dataframe from the bag using the `bag.to_dataframe()` and save the content in parquet files with `.to_parquet()`

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import re
import time
import glob

import dask
import dask.dataframe as dd
import dask.bag as db
from dask.distributed import Client, SSHCluster

# %% [markdown]
# ## Cluster up

# %%
cluster = SSHCluster(
            ["bhbh-1", 'bhbh-1', "bhbh-2", "bhbh-3", "bhbh-4", "bhbh-5"],
            connect_options={"client_keys": "/path_to_my_key"},
            worker_options={"n_workers": 2,   #best set-up from benchmark
                            "nthreads": 2},
            scheduler_options={"port": 8786, "dashboard_address": ":8787"}
            )
# Out:
# 2023-06-16 14:27:19,942 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:19,940 - distributed.scheduler - INFO - State start
# 2023-06-16 14:27:19,946 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:19,943 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-2h_ywjgb', purging
# 2023-06-16 14:27:19,948 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:19,946 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-limx3khf', purging
# 2023-06-16 14:27:19,955 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:19,955 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.140:8786
# 2023-06-16 14:27:20,949 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:20,948 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:39625'
# 2023-06-16 14:27:20,959 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:20,958 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.140:36241'
# 2023-06-16 14:27:21,097 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,095 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:36587'
# 2023-06-16 14:27:21,102 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,098 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.21:43363'
# 2023-06-16 14:27:21,451 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,449 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:40307'
# 2023-06-16 14:27:21,455 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,453 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.220:43119'
# 2023-06-16 14:27:21,472 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,471 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-r6d59biu', purging
# 2023-06-16 14:27:21,474 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,471 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-6dlw5eyu', purging
# 2023-06-16 14:27:21,477 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:39687
# 2023-06-16 14:27:21,480 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.21:39687
# 2023-06-16 14:27:21,482 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -          dashboard at:          10.67.22.21:46267
# 2023-06-16 14:27:21,483 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-16 14:27:21,484 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-16 14:27:21,486 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -               Threads:                          2
# 2023-06-16 14:27:21,486 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -                Memory:                   3.88 GiB
# 2023-06-16 14:27:21,487 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-qhzyuxnd
# 2023-06-16 14:27:21,488 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-16 14:27:21,489 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,475 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.21:46271
# 2023-06-16 14:27:21,554 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,550 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:38253'
# 2023-06-16 14:27:21,558 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,554 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.31:36953'
# 2023-06-16 14:27:21,714 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:35551
# 2023-06-16 14:27:21,721 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.140:35551
# 2023-06-16 14:27:21,722 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO -          dashboard at:         10.67.22.140:40171
# 2023-06-16 14:27:21,723 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-16 14:27:21,724 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-16 14:27:21,725 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO -               Threads:                          2
# 2023-06-16 14:27:21,730 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO -                Memory:                   3.88 GiB
# 2023-06-16 14:27:21,731 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,711 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-1cafvr1g
# 2023-06-16 14:27:21,732 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,712 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-16 14:27:21,760 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:21,758 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.140:37909
# 2023-06-16 14:27:22,086 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,083 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-oeegerds', purging
# 2023-06-16 14:27:22,088 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,084 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-kajnhlbh', purging
# 2023-06-16 14:27:22,113 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,108 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:33153
# 2023-06-16 14:27:22,114 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO -          Listening to:   tcp://10.67.22.220:33153
# 2023-06-16 14:27:22,118 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO -          dashboard at:         10.67.22.220:39329
# 2023-06-16 14:27:22,122 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-16 14:27:22,122 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-16 14:27:22,123 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO -               Threads:                          2
# 2023-06-16 14:27:22,129 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO -                Memory:                   3.88 GiB
# 2023-06-16 14:27:22,130 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO -       Local Directory: /tmp/dask-scratch-space/worker-0ebfrb6p
# 2023-06-16 14:27:22,131 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO - -------------------------------------------------
# 2023-06-16 14:27:22,132 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,109 - distributed.worker - INFO -       Start worker at:   tcp://10.67.22.220:41029
# 2023-06-16 14:27:22,218 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,214 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-7t26zcey', purging
# 2023-06-16 14:27:22,220 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,215 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-vd22j0yf', purging
# 2023-06-16 14:27:22,225 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,222 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:37247
# 2023-06-16 14:27:22,231 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,222 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.31:37247
# 2023-06-16 14:27:22,232 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,222 - distributed.worker - INFO -          dashboard at:          10.67.22.31:35117
# 2023-06-16 14:27:22,234 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,222 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.140:8786
# 2023-06-16 14:27:22,234 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,222 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.31:33045
# 2023-06-16 14:27:22,284 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,279 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:43163'
# 2023-06-16 14:27:22,289 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:22,285 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.81:33405'
# 2023-06-16 14:27:23,092 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:23,087 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-9w8lx2yz', purging
# 2023-06-16 14:27:23,097 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:23,088 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-scratch-space/worker-aui1v29a', purging
# 2023-06-16 14:27:23,124 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:23,119 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:46555
# 2023-06-16 14:27:23,125 - distributed.deploy.ssh - INFO - 2023-06-16 14:27:23,119 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.81:45595

# %% [markdown]
# ## Client

# %%
client = Client(cluster)
# Out:
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/distributed/client.py:1388: VersionMismatchWarning: Mismatched versions found
#
# +---------+--------+-----------+------------------+
# | Package | Client | Scheduler | Workers          |
# +---------+--------+-----------+------------------+
# | tornado | 6.3.2  | 6.3.2     | {'6.3.2', '6.2'} |
# +---------+--------+-----------+------------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %%
client
# Out:
# <Client: 'tcp://10.67.22.140:8786' processes=10 threads=20, memory=38.82 GiB>

# %% [markdown]
# ## Creating list of directories

# %%
dir_path = '/mnt/bhbh/fiducial_Hrad_5M/sevn_output_*'
dir_list = glob.glob(dir_path)

# %% [markdown]
# ## Creating the bag list of paths

# %%
bag = db.from_sequence([[dir_ + f'/0/output_{thread}.csv', 
                    dir_ + f'/0/evolved_{thread}.dat',
                    dir_ + f'/0/logfile_{thread}.dat'] for dir_ in dir_list for thread in range(30)], npartitions=30*60)  #selecting   #partitions= #threads

# %% [markdown]
# ## Pre-processing function for the bag_of_thread

# %%
def preprocessing_bag_of_thread(paths):
    
    #lists of columns to read for each file and corresponding type
    output_column_to_read = ['name', 'Mass_0', 'RemnantType_0', 'Mass_1', 'RemnantType_1',
                         'Semimajor','Eccentricity','GWtime','BWorldtime']

    output_column_type = ['string', 'float64', 'int64', 'float64', 'int64',
                      'float64', 'float64', 'float64', 'float64']

    evolved_column_to_read = ['name', 'Mass_0', 'Z_0', 'SN_0', 'Mass_1', 'SN_1', 'a', 'e']


    evolved_column_type = ['string', 'float64', 'float64', 'string', 'float64', 
                      'string', 'float64', 'float64']

    drop_list = ['RemnantType_0',  'RemnantType_1']
    
   
    #Preprocessing OUTPUT
    
    #reading the file
    output = pd.read_csv(paths[0], usecols=output_column_to_read, dtype=dict(zip(output_column_to_read, output_column_type))).\
                rename(columns={'Mass_0':'Mass_0_out', 'Mass_1':'Mass_1_out'})
    
    #mask to select only the binaries we are interested in
    idxBHBH=(output.RemnantType_0==6) & (output.RemnantType_1==6) & (output.Semimajor.notnull())
    output=output[idxBHBH]    
    
    
    #preprocessing EVOLVED
      
    #reading the file
    evolved = pd.read_table(paths[1], sep='\s+', usecols=evolved_column_to_read, dtype=dict(zip(evolved_column_to_read, evolved_column_type)))                
    
    #extracting alpha with a regex
    alpha = float(re.findall(r".+(?<=A)(.*)(?=L)", paths[1])[0])
    evolved['alpha'] = alpha
    
    
    #preprocessing LOGFILE
    
    logfile = pd.read_csv(paths[2], header=None)
    
    
    #extracting informations with regex

    df_RLO = logfile[0].str.extract(r"B;((?:\d*\_)?\d+);(\d+);RLO_BEGIN;").\
                dropna().\
                rename(columns={0:'name', 1:'ID'}).\
                groupby(['name']).\
                size().to_frame(name='RLO').\
                reset_index()

    df_CE = logfile[0].str.extract(r"B;((?:\d*\_)?\d+);(\d+);CE;").\
                dropna().\
                rename(columns={0:'name', 1:'ID'}).\
                groupby(['name']).\
                size().to_frame(name='CE').\
                reset_index()

    df_BSN = logfile[0].str.extract(r"B;((?:\d*\_)?\d+);(\d+);BSN;").\
                dropna().\
                rename(columns={0:'name', 1:'ID'}).\
                groupby(['name']).\
                size().to_frame(name='BSN').\
                reset_index()

    
    #MERGE
    bhbh = evolved.merge(output, on=['name'], how='inner').\
                   merge(df_RLO, on=['name'], how='left').\
                   merge(df_CE,  on=['name'], how='left').\
                   merge(df_BSN, on=['name'], how='left').\
                   fillna(value=0).\
                   drop(columns=drop_list)
    
    
    #add some useful columns
    bhbh['tdelay'] = bhbh['GWtime'] + bhbh['BWorldtime']

    bhbh['Mass_max_out'] = bhbh['Mass_1_out']
    bhbh['Mass_max_out'] = bhbh['Mass_max_out'].\
                            where(cond=(bhbh['Mass_max_out'] > bhbh['Mass_0_out']), other=bhbh['Mass_0_out'])

    bhbh['q'] = bhbh['Mass_1_out']/bhbh['Mass_0_out']
    bhbh['q'] = bhbh['q'].\
                where(cond=(bhbh['Mass_1_out'] < bhbh['Mass_0_out']), other=bhbh['Mass_0_out']/bhbh['Mass_1_out'])

    bhbh['Mass_chirp'] = ((bhbh['Mass_0_out'] * bhbh['Mass_1_out'])**(3/5))/((bhbh['Mass_0_out'] + bhbh['Mass_1_out'])**(1/5))
    
    
    return bhbh #a pandas dataframe

# %% [markdown]
# ## Map the preprocessing function to the bag

# %%
# %%time
bag_of_df = bag.map(preprocessing_bag_of_thread)
# Out:
# CPU times: user 142 ms, sys: 1.46 ms, total: 144 ms
# Wall time: 143 ms

# %% [markdown]
# ## Concat the dataframes

# %%
# %%time
bag_of_dicts = bag_of_df.map(lambda df: df.to_dict(orient='records')).flatten() #trasforming to a bag of dictionaries to use .to_dataframe()
# Out:
# CPU times: user 5.46 ms, sys: 3.38 ms, total: 8.85 ms
# Wall time: 8.9 ms

# %%
# %%time
bhbh = bag_of_dicts.to_dataframe()
# Out:
# CPU times: user 639 ms, sys: 9.42 ms, total: 648 ms
# Wall time: 22.8 s

# %% [markdown]
# ## Save to parquet

# %%
# %%time
bhbh.to_parquet('/mnt/bhbh/bag_all_dataset/')
# Out:
# CPU times: user 14.3 s, sys: 1.45 s, total: 15.8 s
# Wall time: 1h 37min 3s

# %% [markdown]
# ## Compute (if we do not want to save the results)

# %% [raw]
# %%time
# bhbh.compute()
# bhbh.head()

# %% [markdown]
# ## Final dataframe

# %%
bhbh = dd.read_parquet('/mnt/bhbh/bag_all_dataset/part.*.parquet')

# %%
bhbh.head()
# Out:
#                 name   Mass_0     Z_0         SN_0  Mass_1         SN_1  \
# 0  0_186500805616303   24.025  0.0004  rapid_gauNS  15.586  rapid_gauNS
# 1  0_502130275753280   39.240  0.0004  rapid_gauNS  37.312  rapid_gauNS
# 2  0_201673565337120   61.947  0.0004  rapid_gauNS  30.179  rapid_gauNS
# 3  0_929528790266714  135.386  0.0004  rapid_gauNS  78.408  rapid_gauNS
# 4  0_583722007414750   51.010  0.0004  rapid_gauNS  50.206  rapid_gauNS
#
#          a        e  alpha  Mass_0_out  ...  Eccentricity        GWtime  \
# 0     56.1  0.00704    1.0    9.050055  ...      0.028653  7.108607e+03
# 1   1180.0  0.07820    1.0   38.336310  ...      0.006686  1.274892e+09
# 2   5040.0  0.22100    1.0   59.190780  ...      0.277687  1.390318e+12
# 3  20600.0  0.75400    1.0   47.067630  ...      0.777802  4.464742e+14
# 4   2400.0  0.29900    1.0   49.445770  ...      0.005092  3.798065e+09
#
#    BWorldtime  RLO   CE  BSN        tdelay  Mass_max_out         q  Mass_chirp
# 0   10.624610  2.0  0.0    2  7.119232e+03      9.050055  0.928217    7.589440
# 1    5.217448  2.0  0.0    2  1.274892e+09     38.336310  0.950738   32.539204
# 2    6.160173  0.0  0.0    2  1.390318e+12     59.190780  0.357987   30.060437
# 3    3.399872  0.0  0.0    2  4.464742e+14     47.067630  0.742702   35.234364
# 4    4.275696  2.0  0.0    2  3.798065e+09     49.445770  0.985839   42.738950
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Close the cluster

# %%
cluster.close()
